# %%
# !python ../src/preprocess.py

# %%
# !python ../src/model.py

# %%
# !python ../src/train.py
# Out:
# Epoch [200/2000] - Loss: 0.3116
# Epoch [400/2000] - Loss: 0.2267
# Epoch [600/2000] - Loss: 0.1822
# Epoch [800/2000] - Loss: 0.1392
# Epoch [1000/2000] - Loss: 0.1000
# Epoch [1200/2000] - Loss: 0.0683
# Epoch [1400/2000] - Loss: 0.0451
# Epoch [1600/2000] - Loss: 0.0281
# Epoch [1800/2000] - Loss: 0.0174
# Epoch [2000/2000] - Loss: 0.0112
# Model saved to artifacts/model.pth

# %%
# !python ../src/evaluate.py
# Out:
# 📊 Evaluation Metrics
#
# Accuracy : 0.7903
# Precision: 0.7535
# Recall   : 0.75
# F1-score : 0.7498
#
# Confusion Matrix:
#  [[16  3  1]
#  [ 4  7  1]
#  [ 3  1 26]]
#
# Classification Report:
#
#                    precision    recall  f1-score   support
#
#            Normal       0.70      0.80      0.74        20
#            Hernia       0.64      0.58      0.61        12
# Spondylolisthesis       0.93      0.87      0.90        30
#
#          accuracy                           0.79        62
#         macro avg       0.75      0.75      0.75        62
#      weighted avg       0.80      0.79      0.79        62

# %% [markdown]
# The model achieves 79% accuracy on multiclass spine disorder classification.
# Performance is excellent for Spondylolisthesis (F1 = 0.90), moderate for Normal (0.74), and weaker for Hernia (0.61).
# Most misclassifications occur between Hernia and Normal, indicating overlapping feature distributions.

# %%
# !python ../src/predict.py
# Out:
# Prediction : Hernia
# Probabilities: [[0.000000e+00 1.000000e+00 4.756362e-29]]
